# %%
l=["apple","orange","apple","grape","apple","banana"]
l.index('apple')?

# %%
def insertAtBegin(self, data):
    new_node = Node(data)
    if self.head is None:
        self.head = new_node
        return
    else:
        new_node.next = self.head
        self.head = new_node

# %%
s = {'a'}
l = list(s)
print(l)

# %%
def func(name, age, aadhar=None, phone=None, **kwargs):
    print('name' - name)
    print('age' - age)
    
    if 'email' in kwargs:
        print("Email is an extra field")
    
    if aadhar is not None:
        print('aadhar is extra field', aadhar)
    
    if phone is not None:
        print('phone' - phone)
        
try :
    func('alex', 30, phone='1234567890', email = 'a@gmail.com')
except:
    print(' name and age are mandatory')

# %%
def func(name, age, aadhar=None, phone=None, **kwargs):
    print('name- ', name)
    print('age-', age)
    
    if 'email' in kwargs:
        print("Email is an extra field")
    
    if aadhar is not None:
        print('aadhar is extra field', aadhar)
    
    if phone is not None:
        print('phone' - phone)
        
func('alex', 30, phone='1234567890', email = 'a@gmail.com')

# %%
def Employee(name, age, aadhar=None, phone=None, **kwargs):
    print('name- ', name)
    print('age-', age)

    if 'email' in kwargs:
        print("Email is an extra field")

    if aadhar is not None:
        print('aadhar is extra field', aadhar)

    if phone is not None:
        print('phone -',  phone)

    
try:       
    Employee('gowardhan', 50, phone='9955668877', email = 'a@gmail.com')
    print()
    Employee( phone='9898567890', email = 'hjja@gmail.com')
    print()
except:
    print('age and name are mandatory')

# %%
l = ['a', 'b', 'c', 'a', 'b', 'a', 'c', 'a', 'b']
t = input('enter a target charcter to change last 2 occurences: ')
c = l.count(t)
op = []
print(c
     )
for i in l:
    if i==t and c!=2 and c!=1:
        c -= 1
    
    elif c==2 or c==1:
        op += t.upper()
    
    else:
        op += i
        
print(op)

# %%
l = ['a', 'b', 'c', 'a', 'b', 'a', 'c', 'a', 'b']
t = input('enter a target charcter to change last 2 occurences: ')
c = l.count(t)
x=[]
coun=0
for i in l:
    if i == t:
        coun+=1
        if coun > (c-2):
            x.append(i.upper())
        else :
            x.append(i)
    else :
        x.append(i)
print(x)

# %%
#[8:35 AM] samba (Guest)
data=[{"name":"jay","age":7},{"name":"vedha","age":6}]

[8:35 AM] samba (Guest)
add email key and some value to each and every dict in the list

# %%
data=[{"name":"jay","age":7},{"name":"vedha","age":6}]
emails =['g@gmaul.com','go@gmail.com']
for i,j in data,emails:
    i['email']=j
print(data)

# %%
l1=()
z1=[1,2,3]
z2=[4,5,6]
d=[]
for i in range(len(z1)):
    s=[]
    s.append(z1[i])
    s.append(z2[i])
    s=tuple(s)
    d.append(s)
d

# %%
l=[1,2,3,4,5]
c=0
for i in l:
    if i%2==0:
        print('yes')
        break
    else :
        c+=1
if c0:
    print('no')

# %%
import re

# Text containing both sets of data
# text = """
# Bank A/c No. : 737301507581 ESI A/c No : Designation : QUALITY ANALYST Bank Name : ICICI BANK UAN : 101389794577 Net Paid Days : 31 Earnings Amount Rs. Deductions Amount Rs. BASIC SALARY 13,746.00 PF 1,800.00 HRA 6,873.00 LOP 0.00 CONVEYANCE ALLOWANCE 1,131.00 ESI 170.00 CHILDREN EDUCATION ALLOWANCE 0.00 PT 200.00 LEAVE TRAVEL ALLOWANCE 0.00 TDS 0.00 MEDICAL ALLOWANCE 0.00 TRANSPORT 2,000.00 FOOD ALLOWANCE 0.00 SODEXHO 0.00 EDUCATION ALLOWANCE 0.00 ADVANCE 0.00 SPECIAL ALLOWANCE 869.00 MEAL VOUCHERS 0.00 Bonus per month 0.00 OTHER DED. 0.00 INCENTIVES/ARRER