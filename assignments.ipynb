# %%
"""
addition, subtraction, multiplication operations are not supported by dictionary. 
Write a program to provide addition, subtraction, and multiplication operations to dictionary. 
Write your own definition for operations.
"""
a={1:2,3:4}
b={5:6,7:8}
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       6 a={1:2,3:4}
#       7 b={5:6,7:8}
# ----> 8 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
dict([(1,2),(3,4)])
# Out:
# {1: 2, 3: 4}

# %%
class MyDict(dict):
    pass
a=MyDict([(1,2),(3,4)])
print(a)
# Out:
# {1: 2, 3: 4}

# %%
class MyDict(dict):
    pass
a=MyDict([(1,2),(3,4)])
b=MyDict([(5,6),(7,8)])
print(a,b)
# Out:
# {1: 2, 3: 4} {5: 6, 7: 8}

# %%
class MyDict(dict):
    pass
a=MyDict([(1,2),(3,4)])
b=MyDict([(5,6),(7,8)])
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 a=MyDict([(1,2),(3,4)])
#       4 b=MyDict([(5,6),(7,8)])
# ----> 5 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'MyDict' and 'MyDict'

# %%
class MyDict(dict):
    def __add__(self1, self2):
        import pdb;pdb.set_trace()
a=MyDict([(1,2),(3,4)])
b=MyDict([(5,6),(7,8)])
print(a+b)

# %%
from collections import UserDict

# %%
class MyDict(UserDict):
    def __add__(self1, self2):
        import pdb;pdb.set_trace()
a=MyDict([(1,2),(3,4)])
b=MyDict([(5,6),(7,8)])
print(a+b)

# %%
class MyList(list):
    pass
s=MyList([1,2,3,4,5])
print(s)
# Out:
# [1, 2, 3, 4, 5]

# %%
class MyList(list):
    pass
s=MyList([1,2,3,4,5])
print(s)

# %%
f=open("b.jpeg", "rb")
data = f.read()
print(data)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\x06\x06\x06\x06\x07\x06\x07\x08\x08\x07\n\x0b\n\x0b\n\x0f\x0e\x0c\x0c\x0e\x0f\x16\x10\x11\x10\x11\x10\x16"\x15\x19\x15\x15\x19\x15"\x1e$\x1e\x1c\x1e$\x1e6*&&*6>424>LDDL_Z_||\xa7\x01\x06\x06\x06\x06\x07\x06\x07\x08\x08\x07\n\x0b\n\x0b\n\x0f\x0e\x0c\x0c\x0e\x0f\x16\x10\x11\x10\x11\x10\x16"\x15\x19\x15\x15\x19\x15"\x1e$\x1e\x1c\x1e$\x1e6*&&*6>424>LDDL_Z_||\xa7\xff\xc2\x00\x11\x08\x06?\x04\xb0\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x001K\x11,\x01\x00\n\x8a\'.\xbcu\x9c\xcb5\x87=\xf3\xd6e5\x80\xa5"P\x00\x01I@\x05\x00\x12\x88\xa2(\x02\xa0\xa9@\x00\tTH(\x00\n \x00J"\x88R\x00\x05\tB(\x94\x12\x80\x16\nR,\x00\xa9@\x15H\x00\x00\x14\x80\x
# ...
